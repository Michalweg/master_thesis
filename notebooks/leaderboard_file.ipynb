# %%
import os 
os.chdir('..')

# %%
import pandas as pd
from pathlib import Path
from src.utils import read_json

tdmr_data = pd.read_csv("leaderboard-generation/tdm_annotations.tsv", sep="\t")

# %%
def change_to_float(value):
    try:
        return float(value)
    except:
        print(value)
        return value


def read_and_process_result_data(result_file_path: str, result_file_column: str = '') -> pd.DataFrame:
    result_json_file = read_json(Path(result_file_path))
    df = pd.DataFrame.from_dict(result_json_file)
    df['PaperName'] = df['PaperName'] + ".pdf"
    return df 

def handle_list_as_values_within_result_column(df: pd.DataFrame, result_column: str) -> pd.DataFrame:
    if result_column in df.columns:
        df_exploded = df.explode(result_column, ignore_index=True)
        df_exploded[result_column] = df_exploded[result_column].apply(lambda x: change_to_float(x))
        df_exploded['float'] = df_exploded[result_column].apply(lambda x: True if type(x) == float else False)
        df_exploded = df_exploded.drop("float", axis=1)
        return df_exploded
    else:
        print(f"There is no result column:{result_column} within these columns: {df.columns}")
        return df

# %%
df = read_and_process_result_data("tdmr_extraction/gpt-4o/with_captions_updated_tables_24_03_new_table_representation/processed_tdmr_extraction.json")

# %%
common_papers = list(set(df['PaperName'].unique()).intersection(tdmr_data['PaperName'].unique()))
len(common_papers)
# Out:
# 3

# %%
common_papers
# Out:
# ['1906.05012.pdf', '1909.02188.pdf', '1811.09242.pdf']

# %%
df[df['PaperName'].isin(common_papers)][['Task', 'Dataset', 'Metric', 'Result']].head(3)
# Out:
#                                 Task Dataset    Metric  \
# 0  Intent Detection and Slot Filling    ATIS  Accuracy
# 1  Intent Detection and Slot Filling    ATIS  Accuracy
# 2  Intent Detection and Slot Filling    ATIS  Accuracy
#
#                                               Result
# 0  [92.6, 91.1, 93.6, 94.1, 96.8, 96.4, 95.0, 96....
# 1           [96.2, 96.1, 96.7, 95.2, 96, 96.6, 96.9]
# 2                           [96.9, 96.5, 97.5, 97.5]

# %%
tdmr_data[tdmr_data['PaperName'].isin(common_papers[:3])][['Task', 'Dataset', 'Metric', 'Result']].head(3)
# Out:
#              Task   Dataset   Metric  Result
# 79  Summarization  Gigaword  ROGUE-1   39.11
# 80  Summarization  Gigaword  ROGUE-2   19.78
# 81  Summarization  Gigaword  ROGUE-L   36.87

# %% [markdown]
# ### Comparing results on 3 random papers

# %%
papers_to_compare = common_papers[:3]
papers_to_compare
# Out:
# ['1811.09242.pdf', '1909.02188.pdf', '1906.05012.pdf']

# %%
compare_df = df[df['PaperName'].isin(papers_to_compare)]
compare_df.shape
# Out:
# (60, 5)

# %%
compare_tdmr_data = tdmr_data[tdmr_data['PaperName'].isin(papers_to_compare)]
compare_tdmr_data.shape
# Out:
# (15, 7)

# %% [markdown]
# #### Extracted datasets comparison

# %%
compare_df['Dataset'].unique()
# Out:
# array(['ATIS', 'Gigaword', "'Gigaword'", 'SemEval 2013 Task 13'],
#       dtype=object)

# %%
compare_tdmr_data['Dataset'].unique()
# Out:
# array(['Gigaword', 'SemEval 2013 Task 13', 'SemEval 2010 Task 14', 'ATIS',
#        'SNIPS'], dtype=object)

# %% [markdown]
# ### First paper

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[0]]
# Out:
#                     Task               Dataset  \
# 48  Word Sense Induction  SemEval 2013 Task 13
# 49  Word Sense Induction  SemEval 2013 Task 13
# 50  Word Sense Induction  SemEval 2013 Task 13
# 51  Word Sense Induction  SemEval 2013 Task 13
# 52  Word Sense Induction  SemEval 2013 Task 13
# 53  Word Sense Induction  SemEval 2013 Task 13
# 54  Word Sense Induction  SemEval 2013 Task 13
# 55  Word Sense Induction  SemEval 2013 Task 13
# 56  Word Sense Induction  SemEval 2013 Task 13
# 57  Word Sense Induction  SemEval 2013 Task 13
# 58  Word Sense Induction  SemEval 2013 Task 13
# 59  Word Sense Induction  SemEval 2013 Task 13
#
#                                         Metric  \
# 48  Fuzzy normalized mutual information (FNMI)
# 49  Fuzzy normalized mutual information (FNMI)
# 50  Fuzzy normalized mutual information (FNMI)
# 51  Fuzzy normalized mutual information (FNMI)
# 52  Fuzzy normalized mutual information (FNMI)
# 53  Fuzzy normalized mutual information (FNMI)
# 54  Fuzzy normalized mutual information (FNMI)
# 55  Fuzzy normalized mutual information (FNMI)
# 56  Fuzzy normalized mutual information (FNMI)
# 57  Fuzzy normalized mutual information (FNMI)
# 58  Fuzzy normalized mutual information (FNMI)
# 59  Fuzzy normalized mutual information (FNMI)
#
#                                                Result       PaperName
# 48  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 49  [41.4, 13.3, 8.9, 9, 42.5, 44.1, 41.6, 41.3, 4...  1811.09242.pdf
# 50  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 51  [{'Model': 'LDA', 'S = 5': 41.4, 'S = 25': 13....  1811.09242.pdf
# 52  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 53  [41.4, 13.3, 8.9, 9, 42.5, 44.1, 41.6, 41.3, 4...  1811.09242.pdf
# 54  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 55  [{'Model': 'LDA', 'S = 5': 41.4, 'S = 25': 13....  1811.09242.pdf
# 56  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 57  [41.4, 13.3, 8.9, 9, 42.5, 44.1, 41.6, 41.3, 4...  1811.09242.pdf
# 58  [6.5, 6.0, 6.96, 1.6, 3.5, 7.14, 7.62, 7.69, 7...  1811.09242.pdf
# 59  [41.4, 13.3, 8.9, 9, 42.5, 44.1, 41.6, 41.3, 4...  1811.09242.pdf

# %%
compare_tdmr_data.columns
# Out:
# Index(['PaperURL', 'PaperName', 'Task', 'Dataset', 'Metric', 'Result',
#        'Comment'],
#       dtype='object')

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#              Task   Dataset   Metric       PaperName  Result
# 79  Summarization  Gigaword  ROGUE-1  1906.05012.pdf   39.11
# 80  Summarization  Gigaword  ROGUE-2  1906.05012.pdf   19.78
# 81  Summarization  Gigaword  ROGUE-L  1906.05012.pdf   36.87

# %% [markdown]
# ### Second paper

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[1]]
# Out:
#                      Task       Dataset  \
# 228  Word Sense Induction  SemEval 2010
# 229  Word Sense Induction  SemEval 2013
# 230  Word sense induction  SemEval 2010
# 231  Word sense induction  SemEval 2010
# 232  Word sense induction  SemEval 2013
# 233  Word sense induction  SemEval 2013
#
#                                           Metric       PaperName Result
# 228                                     F1-score  1811.09242.pdf   62.9
# 229                                     F1-score  1811.09242.pdf  24.37
# 230                              V-measure (V-M)  1811.09242.pdf    4.4
# 231                                F-score (F-S)  1811.09242.pdf   62.9
# 232                         Fuzzy B-cubed (F-BC)  1811.09242.pdf  24.37
# 233  Fuzzy normalized mutual information (F-NMI)  1811.09242.pdf  24.37

# %%
papers_to_compare
# Out:
# ['1906.05012.pdf', '1811.09242.pdf', '1909.02188.pdf']

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[1]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                      Task               Dataset  \
# 246  Word Sense Induction  SemEval 2013 Task 13
# 247  Word Sense Induction  SemEval 2013 Task 13
# 248  Word Sense Induction  SemEval 2013 Task 13
# 249  Word Sense Induction  SemEval 2010 Task 14
# 250  Word Sense Induction  SemEval 2010 Task 14
# 251  Word Sense Induction  SemEval 2010 Task 14
#
#                                          Metric       PaperName  Result
# 246  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    9.55
# 247                         Fuzzy B-Cubed (FBC)  1811.09242.pdf   62.20
# 248                                         AVG  1811.09242.pdf   24.37
# 249                               F-Score (F-S)  1811.09242.pdf   62.90
# 250                             V-Measure (V-M)  1811.09242.pdf   10.10
# 251                                         AVG  1811.09242.pdf   25.20

# %% [markdown]
# ### Third paper

# %%
papers_to_compare[2]
# Out:
# '1909.02188.pdf'

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[2]]
# Out:
#                                      Task Dataset            Metric  \
# 78                      Intent Prediction    ATIS          Accuracy
# 79  Sentence-level Semantic Frame Parsing    ATIS  Overall Accuracy
# 80                       Intent Detection    ATIS          Accuracy
#
#          PaperName Result
# 78  1909.02188.pdf   86.5
# 79  1909.02188.pdf   86.5
# 80  1909.02188.pdf   86.5

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[2]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset            Metric  \
# 266  Intent Detection and Slot Filling    ATIS                F1
# 267  Intent Detection and Slot Filling    ATIS          Accuracy
# 268  Intent Detection and Slot Filling    ATIS  Overall-Accuracy
# 269  Intent Detection and Slot Filling   SNIPS                F1
# 270  Intent Detection and Slot Filling   SNIPS          Accuracy
# 271  Intent Detection and Slot Filling   SNIPS  Overall-Accuracy
#
#           PaperName  Result
# 266  1909.02188.pdf    95.9
# 267  1909.02188.pdf    96.9
# 268  1909.02188.pdf    86.5
# 269  1909.02188.pdf    94.2
# 270  1909.02188.pdf    98.0
# 271  1909.02188.pdf    86.9

# %% [markdown]
# ## Updated approach on 07.02

# %%
# result_json_file = 
read_json_new = read_json('tdmr_extraction/gpt-4o/with_captions_updated_tables_24_03_new_table_representation/processed_tdmr_extraction.json')
papers_to_compare = common_papers[:3]
updated_df = pd.DataFrame.from_dict(read_json_new)
updated_df['PaperName'] = updated_df['PaperName'] + ".pdf"
updated_df_exploded = updated_df.explode('Result', ignore_index=True)

# %%
updated_df_exploded
# Out:
#                                   Task               Dataset  \
# 0    Intent Detection and Slot Filling                  ATIS
# 1    Intent Detection and Slot Filling                  ATIS
# 2    Intent Detection and Slot Filling                  ATIS
# 3    Intent Detection and Slot Filling                  ATIS
# 4    Intent Detection and Slot Filling                  ATIS
# ..                                 ...                   ...
# 467               Word Sense Induction  SemEval 2013 Task 13
# 468               Word Sense Induction  SemEval 2013 Task 13
# 469               Word Sense Induction  SemEval 2013 Task 13
# 470               Word Sense Induction  SemEval 2013 Task 13
# 471               Word Sense Induction  SemEval 2013 Task 13
#
#                                          Metric Result       PaperName
# 0                                      Accuracy   92.6  1909.02188.pdf
# 1                                      Accuracy   91.1  1909.02188.pdf
# 2                                      Accuracy   93.6  1909.02188.pdf
# 3                                      Accuracy   94.1  1909.02188.pdf
# 4                                      Accuracy   96.8  1909.02188.pdf
# ..                                          ...    ...             ...
# 467  Fuzzy normalized mutual information (FNMI)   41.9  1811.09242.pdf
# 468  Fuzzy normalized mutual information (FNMI)   44.4  1811.09242.pdf
# 469  Fuzzy normalized mutual information (FNMI)   45.5  1811.09242.pdf
# 470  Fuzzy normalized mutual information (FNMI)   46.6  1811.09242.pdf
# 471  Fuzzy normalized mutual information (FNMI)   46.5  1811.09242.pdf
#
# [472 rows x 5 columns]

# %% [markdown]
# ### First paper

# %%
updated_df_exploded[updated_df_exploded['PaperName'] == papers_to_compare[0]]
# Out:
#                                   Task Dataset    Metric Result  \
# 0    Intent Detection and Slot Filling    ATIS  Accuracy   92.6
# 1    Intent Detection and Slot Filling    ATIS  Accuracy   91.1
# 2    Intent Detection and Slot Filling    ATIS  Accuracy   93.6
# 3    Intent Detection and Slot Filling    ATIS  Accuracy   94.1
# 4    Intent Detection and Slot Filling    ATIS  Accuracy   96.8
# ..                                 ...     ...       ...    ...
# 215  Intent Detection and Slot Filling    ATIS  Accuracy   96.9
# 216  Intent Detection and Slot Filling    ATIS  Accuracy   96.9
# 217  Intent Detection and Slot Filling    ATIS  Accuracy   96.5
# 218  Intent Detection and Slot Filling    ATIS  Accuracy   97.5
# 219  Intent Detection and Slot Filling    ATIS  Accuracy   97.5
#
#           PaperName
# 0    1909.02188.pdf
# 1    1909.02188.pdf
# 2    1909.02188.pdf
# 3    1909.02188.pdf
# 4    1909.02188.pdf
# ..              ...
# 215  1909.02188.pdf
# 216  1909.02188.pdf
# 217  1909.02188.pdf
# 218  1909.02188.pdf
# 219  1909.02188.pdf
#
# [220 rows x 5 columns]

# %%
updated_df_exploded['Result'] = updated_df_exploded['Result'].apply(lambda x: change_to_float(x))
updated_df_exploded['float'] = updated_df_exploded['Result'].apply(lambda x: True if type(x) == float else False)
updated_df_exploded_float = updated_df_exploded[updated_df_exploded['float']]
# Out:
# {'Model': 'LDA', 'S = 5': 41.4, 'S = 25': 13.3, 'S = 50': 8.9, 'S = 100': 9}
# {'Model': 'HC', 'S = 5': 42.5, 'S = 25': 44.1, 'S = 50': 41.6, 'S = 100': 41.3}
# {'Model': 'STM', 'S = 5': 44.9, 'S = 25': 44.4, 'S = 50': 44.9, 'S = 100': 41.9}
# {'Model': 'AutoSense', 'S = 5': 44.4, 'S = 25': 45.5, 'S = 50': 46.6, 'S = 100': 46.5}
# {'Model': 'LDA', 'S = 5': 41.4, 'S = 25': 13.3, 'S = 50': 8.9, 'S = 100': 9}
# {'Model': 'HC', 'S = 5': 42.5, 'S = 25': 44.1, 'S = 50': 41.6, 'S = 100': 41.3}
# {'Model': 'STM', 'S = 5': 44.9, 'S = 25': 44.4, 'S = 50': 44.9, 'S = 100': 41.9}
# {'Model': 'AutoSense', 'S = 5': 44.4, 'S = 25': 45.5, 'S = 50': 46.6, 'S = 100': 46.5}

# %%
updated_df_exploded_float[updated_df_exploded_float['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset    Metric       PaperName  \
# 0    Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 1    Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 2    Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 3    Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 4    Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# ..                                 ...     ...       ...             ...
# 215  Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 216  Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 217  Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 218  Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
# 219  Intent Detection and Slot Filling    ATIS  Accuracy  1909.02188.pdf
#
#     Result
# 0     92.6
# 1     91.1
# 2     93.6
# 3     94.1
# 4     96.8
# ..     ...
# 215   96.9
# 216   96.9
# 217   96.5
# 218   97.5
# 219   97.5
#
# [220 rows x 5 columns]

# %%
updated_df_exploded_float[updated_df_exploded_float['PaperName'] == papers_to_compare[1]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                      Task               Dataset  \
# 310  Word Sense Induction  SemEval 2013 Task 13
# 311  Word Sense Induction  SemEval 2013 Task 13
# 312  Word Sense Induction  SemEval 2013 Task 13
# 313  Word Sense Induction  SemEval 2013 Task 13
# 314  Word Sense Induction  SemEval 2013 Task 13
# ..                    ...                   ...
# 467  Word Sense Induction  SemEval 2013 Task 13
# 468  Word Sense Induction  SemEval 2013 Task 13
# 469  Word Sense Induction  SemEval 2013 Task 13
# 470  Word Sense Induction  SemEval 2013 Task 13
# 471  Word Sense Induction  SemEval 2013 Task 13
#
#                                          Metric       PaperName Result
# 310  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    6.5
# 311  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    6.0
# 312  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   6.96
# 313  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    1.6
# 314  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    3.5
# ..                                          ...             ...    ...
# 467  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   41.9
# 468  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   44.4
# 469  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   45.5
# 470  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   46.6
# 471  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf   46.5
#
# [154 rows x 5 columns]

# %%
updated_df_exploded_float[updated_df_exploded_float['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                          PaperName Result
# Task                              Dataset Metric
# Intent Detection and Slot Filling ATIS    Accuracy  1909.02188.pdf   97.5

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset            Metric  \
# 266  Intent Detection and Slot Filling    ATIS                F1
# 267  Intent Detection and Slot Filling    ATIS          Accuracy
# 268  Intent Detection and Slot Filling    ATIS  Overall-Accuracy
# 269  Intent Detection and Slot Filling   SNIPS                F1
# 270  Intent Detection and Slot Filling   SNIPS          Accuracy
# 271  Intent Detection and Slot Filling   SNIPS  Overall-Accuracy
#
#           PaperName  Result
# 266  1909.02188.pdf    95.9
# 267  1909.02188.pdf    96.9
# 268  1909.02188.pdf    86.5
# 269  1909.02188.pdf    94.2
# 270  1909.02188.pdf    98.0
# 271  1909.02188.pdf    86.9

# %% [markdown]
# ### Difference caused:
#
# In the other table within this paper there's a higher value extracted than the one reported by authors

# %% [markdown]
# ### Second paper

# %%
papers_to_compare[1]
# Out:
# '1811.09242.pdf'

# %%
updated_df_exploded['float'] = updated_df_exploded['Result'].apply(lambda x: True if type(x) == float else False)

# %%
updated_df_exploded[(updated_df_exploded['PaperName'] == papers_to_compare[1])].groupby(['Task', 'Dataset', 'Metric'])['Result'].tail()# .groupby(['Task', 'Dataset', 'Metric'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 updated_df_exploded[(updated_df_exploded['PaperName'] == papers_to_compare[1])].groupby(['Task', 'Dataset', 'Metric'])['Task', 'Dataset', 'Metric' ,'Result'].tail()# .groupby(['Task', 'Dataset', 'Metric'])
#
# File ~/Dokumenty_mac/MasterThesis/master_thesis/venv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:1947, in DataFrameGroupBy.__getitem__(self, key)
#    1943 # per GH 23566
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
# -> 1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
#    1951 return super().__getitem__(key)
#
# ValueError: Cannot subset columns with a tuple with more than one element. Use a list instead.

# %%
compare_tdmr_data[(compare_tdmr_data['PaperName'] == papers_to_compare[1]) & (updated_df_exploded['float'] == True)].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
# /var/folders/jm/q7s8glj14mj8tqv8r15tr1wc0000gp/T/ipykernel_11157/2301952649.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   compare_tdmr_data[(compare_tdmr_data['PaperName'] == papers_to_compare[1]) & (updated_df_exploded['float'] == True)].groupby(['Task', 'Dataset', 'Metric']).max()
#                                                                                                                   PaperURL  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                         https://arxiv.org/pdf/1811.09242.pdf
#                                           F-Score (F-S)                               https://arxiv.org/pdf/1811.09242.pdf
#                                           V-Measure (V-M)                             https://arxiv.org/pdf/1811.09242.pdf
#                      SemEval 2013 Task 13 AVG                                         https://arxiv.org/pdf/1811.09242.pdf
#                                           Fuzzy B-Cubed (FBC)                         https://arxiv.org/pdf/1811.09242.pdf
#                                           Fuzzy normalized mutual information (FNMI)  https://arxiv.org/pdf/1811.09242.pdf
#
#                                                                                            PaperName  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                         1811.09242.pdf
#                                           F-Score (F-S)                               1811.09242.pdf
#                                           V-Measure (V-M)                             1811.09242.pdf
#                      SemEval 2013 Task 13 AVG                                         1811.09242.pdf
#                                           Fuzzy B-Cubed (FBC)                         1811.09242.pdf
#                                           Fuzzy normalized mutual information (FNMI)  1811.09242.pdf
#
#                                                                                       Result  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                          25.20
#                                           F-Score (F-S)                                62.90
#                                           V-Measure (V-M)                              10.10
#                      SemEval 2013 Task 13 AVG                                          24.37
#                                           Fuzzy B-Cubed (FBC)                          62.20
#                                           Fuzzy normalized mutual information (FNMI)    9.55
#
#                                                                                      Comment
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                            NaN
#                                           F-Score (F-S)                                  NaN
#                                           V-Measure (V-M)                                NaN
#                      SemEval 2013 Task 13 AVG                                            NaN
#                                           Fuzzy B-Cubed (FBC)                            NaN
#                                           Fuzzy normalized mutual information (FNMI)     NaN

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[1]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                      Task               Dataset  \
# 246  Word Sense Induction  SemEval 2013 Task 13
# 247  Word Sense Induction  SemEval 2013 Task 13
# 248  Word Sense Induction  SemEval 2013 Task 13
# 249  Word Sense Induction  SemEval 2010 Task 14
# 250  Word Sense Induction  SemEval 2010 Task 14
# 251  Word Sense Induction  SemEval 2010 Task 14
#
#                                          Metric       PaperName  Result
# 246  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    9.55
# 247                         Fuzzy B-Cubed (FBC)  1811.09242.pdf   62.20
# 248                                         AVG  1811.09242.pdf   24.37
# 249                               F-Score (F-S)  1811.09242.pdf   62.90
# 250                             V-Measure (V-M)  1811.09242.pdf   10.10
# 251                                         AVG  1811.09242.pdf   25.20

# %% [markdown]
# ### Third paper

# %%
third_paper_json_file_path = '/Users/Michal/Dokumenty_mac/MasterThesis/master_thesis/tdmr_extraction/gpt-4o/with_captions_updated_tables_07_02_new_table_representation/1909.02188/1909.02188_tdmr_extraction.json'
third_paper_json_file = read_json(Path(third_paper_json_file_path))
thrid_papeR_df = pd.DataFrame.from_dict(third_paper_json_file)

# %%
thrid_paper_df = thrid_papeR_df.explode('Result', ignore_index=True)

# %%
updated_df_exploded[updated_df_exploded['PaperName'] == papers_to_compare[2]].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                                Result  \
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           88.6
# Intent Prediction                     ATIS    Accuracy           88.6
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   88.6
# Slot Filling                          ATIS    F1                  NaN
#
#                                                                      PaperName  \
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy          1909.02188.pdf
# Intent Prediction                     ATIS    Accuracy          1909.02188.pdf
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy  1909.02188.pdf
# Slot Filling                          ATIS    F1                1909.02188.pdf
#
#                                                                 float
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           True
# Intent Prediction                     ATIS    Accuracy           True
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   True
# Slot Filling                          ATIS    F1                 True

# %%
thrid_paper_df['float'] = thrid_paper_df['Result'].apply(lambda x: True if type(x) == float else False)
thrid_paper_df[thrid_paper_df['float'] == True].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                                Result  float
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           97.5   True
#                                       SNIPS   Accuracy           99.0   True
# Intent Prediction                     ATIS    Accuracy           97.5   True
#                                       SNIPS   Accuracy           99.0   True
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   88.6   True
#                                       SNIPS   Overall Accuracy   92.9   True
# Slot Filling                          ATIS    F1                 96.1   True
#                                               F1 Score           96.1   True
#                                       SNIPS   F1                 97.0   True
#                                               F1 Score           97.0   True

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[2]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset            Metric  \
# 266  Intent Detection and Slot Filling    ATIS                F1
# 267  Intent Detection and Slot Filling    ATIS          Accuracy
# 268  Intent Detection and Slot Filling    ATIS  Overall-Accuracy
# 269  Intent Detection and Slot Filling   SNIPS                F1
# 270  Intent Detection and Slot Filling   SNIPS          Accuracy
# 271  Intent Detection and Slot Filling   SNIPS  Overall-Accuracy
#
#           PaperName  Result
# 266  1909.02188.pdf    95.9
# 267  1909.02188.pdf    96.9
# 268  1909.02188.pdf    86.5
# 269  1909.02188.pdf    94.2
# 270  1909.02188.pdf    98.0
# 271  1909.02188.pdf    86.9

# %%
compare_tdmr_data
# Out:
#                                  PaperURL       PaperName  \
# 79   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 80   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 81   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 246  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 247  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 248  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 249  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 250  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 251  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 266  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 267  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 268  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 269  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 270  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 271  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
#
#                                   Task               Dataset  \
# 79                       Summarization              Gigaword
# 80                       Summarization              Gigaword
# 81                       Summarization              Gigaword
# 246               Word Sense Induction  SemEval 2013 Task 13
# 247               Word Sense Induction  SemEval 2013 Task 13
# 248               Word Sense Induction  SemEval 2013 Task 13
# 249               Word Sense Induction  SemEval 2010 Task 14
# 250               Word Sense Induction  SemEval 2010 Task 14
# 251               Word Sense Induction  SemEval 2010 Task 14
# 266  Intent Detection and Slot Filling                  ATIS
# 267  Intent Detection and Slot Filling                  ATIS
# 268  Intent Detection and Slot Filling                  ATIS
# 269  Intent Detection and Slot Filling                 SNIPS
# 270  Intent Detection and Slot Filling                 SNIPS
# 271  Intent Detection and Slot Filling                 SNIPS
#
#                                          Metric  Result Comment
# 79                                      ROGUE-1   39.11     NaN
# 80                                      ROGUE-2   19.78     NaN
# 81                                      ROGUE-L   36.87     NaN
# 246  Fuzzy normalized mutual information (FNMI)    9.55     NaN
# 247                         Fuzzy B-Cubed (FBC)   62.20     NaN
# 248                                         AVG   24.37     NaN
# 249                               F-Score (F-S)   62.90     NaN
# 250                             V-Measure (V-M)   10.10     NaN
# 251                                         AVG   25.20     NaN
# 266                                          F1   95.90     NaN
# 267                                    Accuracy   96.90     NaN
# 268                            Overall-Accuracy   86.50     NaN
# 269                                          F1   94.20     NaN
# 270                                    Accuracy   98.00     NaN
# 271                            Overall-Accuracy   86.90     NaN

# %% [markdown]
# ### Experiments based on fixed normalization process

# %%
fixed_df_json_file_path = 'tdmr_extraction/gpt-4o/with_captions_updated_tables_05_04_new_table_representation/processed_tdmr_extraction_test_papers.json'
fixed_data_dict = read_json(fixed_df_json_file_path)

# %%
df = pd.DataFrame.from_dict(fixed_data_dict)
df['PaperName'] = df['PaperName'] + ".pdf"
df = df.explode('Result', ignore_index=True)

# %%
papers_to_compare = df['PaperName'].unique()

# %%
df[df['PaperName'] == papers_to_compare[0]].groupby(["Task", "Dataset", "Metric"])['Result']

# %%
grouped_df = df[df['PaperName'] == papers_to_compare[0]].groupby(['PaperName', 'Task', 'Metric', 'Dataset'])[
    'Result'].max()
grouped_df
# Out:
# PaperName       Task                                   Metric            Dataset
# 1909.02188.pdf  Intent Detection and Slot Filling      'Accuracy'        SNIPS      99.0
#                                                        Accuracy          ATIS       97.5
#                                                                          SNIPS      99.0
#                                                        F1                ATIS       96.1
#                                                                          SNIPS      97.0
#                                                        State-of-the-art  SNIPS      98.0
#                 Sentence-level Semantic Frame Parsing  Overall-Accuracy  ATIS       88.6
#                                                                          SNIPS      92.9
# Name: Result, dtype: object

# %%
grouped_df = df[df['PaperName'] == papers_to_compare[0]].groupby(['PaperName', 'Task', 'Metric', 'Dataset'])['Result'].apply(lambda x: ', '.join(map(str, x))).reset_index()
grouped_df
# Out:
#         PaperName                                   Task            Metric  \
# 0  1909.02188.pdf      Intent Detection and Slot Filling        'Accuracy'
# 1  1909.02188.pdf      Intent Detection and Slot Filling          Accuracy
# 2  1909.02188.pdf      Intent Detection and Slot Filling          Accuracy
# 3  1909.02188.pdf      Intent Detection and Slot Filling                F1
# 4  1909.02188.pdf      Intent Detection and Slot Filling                F1
# 5  1909.02188.pdf      Intent Detection and Slot Filling  State-of-the-art
# 6  1909.02188.pdf  Sentence-level Semantic Frame Parsing  Overall-Accuracy
# 7  1909.02188.pdf  Sentence-level Semantic Frame Parsing  Overall-Accuracy
#
#   Dataset                                             Result
# 0   SNIPS  96.9, 96.7, 97.0, 96.8, 97.5, 97.2, 97.3, 97.0...
# 1    ATIS  92.6, 91.1, 93.6, 94.1, 96.8, 96.4, 95.0, 96.6...
# 2   SNIPS  96.9, 96.7, 97.0, 96.8, 97.5, 97.2, 97.3, 97.0...
# 3    ATIS  94.3, 94.2, 94.8, 95.2, 95.1, 95.5, 95.2, 95.6...
# 4   SNIPS  87.3, 87.8, 88.8, 88.3, 90.0, 93.5, 91.8, 90.5...
# 5   SNIPS                   94.2, 98.0, 86.9, 98, 92.8, 92.9
# 6    ATIS  80.7, 78.9, 82.2, 82.6, 82.2, 85.7, 83.4, 86.0...
# 7   SNIPS  73.2, 74.1, 75.5, 74.6, 81.0, 83.8, 80.9, 78.4...

# %%
tdmr_data[tdmr_data['PaperName'] == papers_to_compare[0]].groupby(["Task", "Dataset", "Metric"])['Result'].max()
# Out:
# Task                               Dataset  Metric
# Intent Detection and Slot Filling  ATIS     Accuracy            96.9
#                                             F1                  95.9
#                                             Overall-Accuracy    86.5
#                                    SNIPS    Accuracy            98.0
#                                             F1                  94.2
#                                             Overall-Accuracy    86.9
# Name: Result, dtype: float64

# %% [markdown]
# ### Results analysis when extending experiment with model/approach/alogrithm information

# %%
combined_results_file_path = "extending_results_extraction_with_author_approach/gpt-4o/tdmr_extraction_with_author_data_combined.json"

# %%
author_model_results_df = read_and_process_result_data(combined_results_file_path)

# %%
author_model_results_df.head(3)
# Out:
#                                 Task Dataset    Metric  Result  \
# 0  Intent Detection and Slot Filling    ATIS        F1  [86.5]
# 1  Intent Detection and Slot Filling    ATIS  Accuracy  [86.5]
# 2  Intent Detection and Slot Filling    ATIS  Accuracy    86.5
#
#                Model       PaperName
# 0  Stack-Propagation  1909.02188.pdf
# 1  Stack-Propagation  1909.02188.pdf
# 2  Stack-Propagation  1909.02188.pdf

# %%
author_model_results_df_with_no_list = handle_list_as_values_within_result_column(author_model_results_df, result_column="Result")

# %%
author_model_results_df_with_no_list = author_model_results_df_with_no_list

# %%
author_model_results_df_with_no_list.head(3)
# Out:
#                                 Task Dataset    Metric  Result  \
# 0  Intent Detection and Slot Filling    ATIS        F1    86.5
# 1  Intent Detection and Slot Filling    ATIS  Accuracy    86.5
# 2  Intent Detection and Slot Filling    ATIS  Accuracy    86.5
#
#                Model       PaperName
# 0  Stack-Propagation  1909.02188.pdf
# 1  Stack-Propagation  1909.02188.pdf
# 2  Stack-Propagation  1909.02188.pdf

# %%
grouped_df = author_model_results_df_with_no_list[author_model_results_df_with_no_list['PaperName'] == common_papers[0]].groupby(['PaperName', 'Task', 'Metric', 'Dataset', 'Model'])[
    'Result'].max()
grouped_df
# Out:
# PaperName       Task           Metric   Dataset     Model
# 1906.05012.pdf  Summarization  ROGUE-1  'Gigaword'  Bi-Directional Selective Encoding with Template model (BiSET)    39.11
#                                                     Bi-directional Selective Encoding with Template (BiSET)          39.11
#                                                     Bi-selective layer                                               39.11
#                                                     BiSET                                                            39.11
#                                                     Fast Rerank                                                      39.11
#                                                     N-Optimal                                                        40.49
#                                                     Retrieve-top                                                     23.46
#                                                     bi-directional selective mechanism                               39.11
#                                ROGUE-2  'Gigaword'  Bi-Directional Selective Encoding with Template model (BiSET)    19.78
#                                                     Bi-directional Selective Encoding with Template (BiSET)          19.78
#                                                     Bi-selective layer                                               19.78
#                                                     BiSET                                                            19.78
#                                                     Fast Rerank                                                      19.78
#                                                     N-Optimal                                                        19.01
#                                                     Retrieve-top                                                      7.67
#                                                     bi-directional selective mechanism                               19.78
#                                ROGUE-L  'Gigaword'  Bi-Directional Selective Encoding with Template model (BiSET)    36.87
#                                                     Bi-directional Selective Encoding with Template (BiSET)          36.87
#                                                     Bi-selective layer                                               36.87
#                                                     BiSET                                                            36.87
#                                                     Fast Rerank                                                      36.87
#                                                     N-Optimal                                                        36.10
#                                                     Retrieve-top                                                     20.94
#                                                     bi-directional selective mechanism                               36.87
# Name: Result, dtype: float64

# %%
tdmr_data[tdmr_data['PaperName'] == common_papers[0]].groupby(["Task", "Dataset", "Metric"])['Result'].max()
# Out:
# Task           Dataset   Metric
# Summarization  Gigaword  ROGUE-1    39.11
#                          ROGUE-2    19.78
#                          ROGUE-L    36.87
# Name: Result, dtype: float64

# %% [markdown]
# ##### Second paper

# %%
grouped_df = \
author_model_results_df_with_no_list[author_model_results_df_with_no_list['PaperName'] == common_papers[1]].groupby(
    ['PaperName', 'Task', 'Metric', 'Dataset', 'Model'])[
    'Result'].max()
grouped_df
# Out:
# PaperName       Task                                   Metric            Dataset  Model
# 1909.02188.pdf  Intent Detection and Slot Filling      Accuracy          ATIS     Our model                      88.6
#                                                                                   Our model + BERT               88.6
#                                                                                   Stack-Propagation              88.6
#                                                                                   Stack-Propagation framework    88.6
#                                                                                   lstm+token-level               88.6
#                                                        F1                ATIS     Our model                      88.6
#                                                                                   Our model + BERT               88.6
#                                                                                   Stack-Propagation              86.5
#                                                                                   Stack-Propagation framework    86.5
#                                                                          SNIPS    Stack-Propagation framework    86.5
#                 Sentence-level Semantic Frame Parsing  Overall-Accuracy  ATIS     Our model                      88.6
#                                                                                   Our model + BERT               88.6
#                                                                                   Stack-Propagation              88.6
#                                                                                   Stack-Propagation framework    88.6
#                                                                                   lstm+token-level               88.6
# Name: Result, dtype: float64

# %%
tdmr_data[tdmr_data['PaperName'] == common_papers[1]].groupby(["Task", "Dataset", "Metric"])['Result'].max()
# Out:
# Task                               Dataset  Metric
# Intent Detection and Slot Filling  ATIS     Accuracy            96.9
#                                             F1                  95.9
#                                             Overall-Accuracy    86.5
#                                    SNIPS    Accuracy            98.0
#                                             F1                  94.2
#                                             Overall-Accuracy    86.9
# Name: Result, dtype: float64

# %%
grouped_df = author_model_results_df_with_no_list[author_model_results_df_with_no_list['PaperName'] == common_papers[2]].groupby(['PaperName', 'Task', 'Metric', 'Dataset', 'Model'])['Result'].apply(lambda x: ', '.join(map(str, x))).reset_index()
grouped_df
# Out:
#          PaperName                  Task  \
# 0   1811.09242.pdf  Word Sense Induction
# 1   1811.09242.pdf  Word Sense Induction
# 2   1811.09242.pdf  Word Sense Induction
# 3   1811.09242.pdf  Word Sense Induction
# 4   1811.09242.pdf  Word Sense Induction
# 5   1811.09242.pdf  Word Sense Induction
# 6   1811.09242.pdf  Word Sense Induction
# 7   1811.09242.pdf  Word Sense Induction
# 8   1811.09242.pdf  Word Sense Induction
# 9   1811.09242.pdf  Word Sense Induction
# 10  1811.09242.pdf  Word Sense Induction
# 11  1811.09242.pdf  Word Sense Induction
# 12  1811.09242.pdf  Word Sense Induction
# 13  1811.09242.pdf  Word Sense Induction
# 14  1811.09242.pdf  Word Sense Induction
# 15  1811.09242.pdf  Word Sense Induction
# 16  1811.09242.pdf  Word Sense Induction
# 17  1811.09242.pdf  Word Sense Induction
# 18  1811.09242.pdf  Word Sense Induction
# 19  1811.09242.pdf  Word Sense Induction
# 20  1811.09242.pdf  Word Sense Induction
# 21  1811.09242.pdf  Word Sense Induction
# 22  1811.09242.pdf  Word Sense Induction
# 23  1811.09242.pdf  Word Sense Induction
# 24  1811.09242.pdf  Word Sense Induction
# 25  1811.09242.pdf  Word Sense Induction
# 26  1811.09242.pdf  Word Sense Induction
# 27  1811.09242.pdf  Word Sense Induction
# 28  1811.09242.pdf  Word Sense Induction
# 29  1811.09242.pdf  Word Sense Induction
# 30  1811.09242.pdf  Word Sense Induction
# 31  1811.09242.pdf  Word Sense Induction
# 32  1811.09242.pdf  Word Sense Induction
# 33  1811.09242.pdf  Word Sense Induction
# 34  1811.09242.pdf  Word Sense Induction
# 35  1811.09242.pdf  Word Sense Induction
#
#                                         Metric               Dataset  \
# 0                                F-Score (F-S)  SemEval 2010 Task 14
# 1                                F-Score (F-S)  SemEval 2010 Task 14
# 2                                F-Score (F-S)  SemEval 2010 Task 14
# 3                                F-Score (F-S)  SemEval 2010 Task 14
# 4                                F-Score (F-S)  SemEval 2010 Task 14
# 5                                F-Score (F-S)  SemEval 2010 Task 14
# 6                                           F1  SemEval 2010 Task 14
# 7                                           F1  SemEval 2010 Task 14
# 8                                           F1  SemEval 2010 Task 14
# 9                                           F1  SemEval 2010 Task 14
# 10                                          F1  SemEval 2010 Task 14
# 11                                          F1  SemEval 2010 Task 14
# 12                                          F1  SemEval 2013 Task 13
# 13                                          F1  SemEval 2013 Task 13
# 14                                          F1  SemEval 2013 Task 13
# 15                                          F1  SemEval 2013 Task 13
# 16                                          F1  SemEval 2013 Task 13
# 17                                          F1  SemEval 2013 Task 13
# 18                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 19                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 20                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 21                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 22                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 23                         Fuzzy B-Cubed (FBC)  SemEval 2013 Task 13
# 24  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 25  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 26  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 27  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 28  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 29  Fuzzy normalized mutual information (FNMI)  SemEval 2013 Task 13
# 30                             V-Measure (V-M)  SemEval 2010 Task 14
# 31                             V-Measure (V-M)  SemEval 2010 Task 14
# 32                             V-Measure (V-M)  SemEval 2010 Task 14
# 33                             V-Measure (V-M)  SemEval 2010 Task 14
# 34                             V-Measure (V-M)  SemEval 2010 Task 14
# 35                             V-Measure (V-M)  SemEval 2010 Task 14
#
#              Model                                             Result
# 0        AutoSense  61.7, 62.9, 61.2, 56.2, 56.4, 57.9, 58.8, 44.4...
# 1   AutoSenses=100                                   61.2, 58.8, 46.5
# 2     AutoSenses=5                                   62.9, 56.2, 44.4
# 3     AutoSenses=7  61.7, 62.9, 61.2, 56.2, 56.4, 57.9, 58.8, 44.4...
# 4     AutoSense−sw                       61.1, 44.4, 45.5, 46.6, 46.5
# 5     AutoSense−wp                       59.3, 44.4, 45.5, 46.6, 46.5
# 6        AutoSense  61.7, 62.9, 61.2, 56.2, 56.4, 57.9, 58.8, 44.4...
# 7   AutoSenses=100                                   61.2, 58.8, 46.5
# 8     AutoSenses=5                                   62.9, 56.2, 44.4
# 9     AutoSenses=7                 62.9, 56.2, 56.4, 57.9, 58.8, 46.6
# 10    AutoSense−sw                       61.1, 44.4, 45.5, 46.6, 46.5
# 11    AutoSense−wp                       59.3, 44.4, 45.5, 46.6, 46.5
# 12       AutoSense  22.16, 22.17, 24.37, 56.2, 56.4, 57.9, 58.8, 4...
# 13  AutoSenses=100                                  21.03, 58.8, 46.5
# 14    AutoSenses=5                                  22.17, 56.2, 44.4
# 15    AutoSenses=7                22.17, 56.2, 56.4, 57.9, 58.8, 46.6
# 16    AutoSense−sw                      21.26, 44.4, 45.5, 46.6, 46.5
# 17    AutoSense−wp  20.69, 56.2, 56.4, 57.9, 58.8, 44.4, 45.5, 46....
# 18       AutoSense  22.16, 22.17, 24.37, 56.2, 56.4, 57.9, 58.8, 4...
# 19  AutoSenses=100                                  21.03, 58.8, 46.5
# 20    AutoSenses=5                                  22.17, 56.2, 44.4
# 21    AutoSenses=7                22.17, 56.2, 56.4, 57.9, 58.8, 46.6
# 22    AutoSense−sw                      21.26, 44.4, 45.5, 46.6, 46.5
# 23    AutoSense−wp  20.69, 56.2, 56.4, 57.9, 58.8, 44.4, 45.5, 46....
# 24       AutoSense        22.16, 22.17, 24.37, 44.4, 45.5, 46.6, 46.5
# 25  AutoSenses=100                                  21.03, 58.8, 46.5
# 26    AutoSenses=5                                  22.17, 56.2, 44.4
# 27    AutoSenses=7                      22.17, 44.4, 45.5, 46.6, 46.5
# 28    AutoSense−sw                      21.26, 44.4, 45.5, 46.6, 46.5
# 29    AutoSense−wp                      20.69, 44.4, 45.5, 46.6, 46.5
# 30       AutoSense             9.8, 10.1, 9.6, 44.4, 45.5, 46.6, 46.5
# 31  AutoSenses=100                                    9.6, 58.8, 46.5
# 32    AutoSenses=5                                         10.1, 44.4
# 33    AutoSenses=7             9.8, 10.1, 9.6, 44.4, 45.5, 46.6, 46.5
# 34    AutoSense−sw                        8.6, 44.4, 45.5, 46.6, 46.5
# 35    AutoSense−wp                        9.2, 44.4, 45.5, 46.6, 46.5

# %%
tdmr_data[tdmr_data['PaperName'] == common_papers[2]].groupby(["Task", "Dataset", "Metric"])['Result'].max()
# Out:
# Task                  Dataset               Metric
# Word Sense Induction  SemEval 2010 Task 14  AVG                                           25.20
#                                             F-Score (F-S)                                 62.90
#                                             V-Measure (V-M)                               10.10
#                       SemEval 2013 Task 13  AVG                                           24.37
#                                             Fuzzy B-Cubed (FBC)                           62.20
#                                             Fuzzy normalized mutual information (FNMI)     9.55
# Name: Result, dtype: float64
