# %%
import pandas as pd
from pathlib import Path
from src.utils import read_json

tdmr_data = pd.read_csv("leaderboard-generation/tdm_annotations.tsv", sep="\t")

# %%
tdmr_data.columns
# Out:
# Index(['PaperURL', 'PaperName', 'Task', 'Dataset', 'Metric', 'Result',
#        'Comment'],
#       dtype='object')

# %%
tdmr_data['PaperName'].nunique()
# Out:
# 43

# %%
result_json_file = read_json('tdmr_extraction/gpt-4o/with_captions_updated_tables/processed_tdmr_extraction.json')
df = pd.DataFrame.from_dict(result_json_file)

# %%
df['PaperName'].nunique()
# Out:
# 21

# %%
df['PaperName'] = df['PaperName'] + ".pdf"

# %%
df['PaperName'].nunique()
# Out:
# 21

# %%
common_papers = list(set(df['PaperName'].unique()).intersection(tdmr_data['PaperName'].unique()))
len(common_papers)
# Out:
# 21

# %%
df[df['PaperName'].isin(common_papers)][['Task', 'Dataset', 'Metric', 'Result']]
# Out:
#                   Task     Dataset      Metric Result
# 0    Language modeling         PTB  Perplexity   65.4
# 1    Language modeling         PTB  Perplexity   58.8
# 2    Language modeling         PTB  Perplexity   58.3
# 3    Language modeling         PTB  Perplexity   56.0
# 4    Language modeling         PTB  Perplexity   58.6
# ..                 ...         ...         ...    ...
# 325  En-Vi Translation  IWSLT 2015        BLEU   31.3
# 326  En-De Translation       WMT14        BLEU   29.9
# 327  En-Fr Translation       WMT14        BLEU   43.5
# 328        Translation  IWSLT 2015        BLEU   31.3
# 329        Translation  IWSLT 2015        BLEU   36.3
#
# [330 rows x 4 columns]

# %%
tdmr_data[tdmr_data['PaperName'].isin(common_papers[:3])][['Task', 'Dataset', 'Metric', 'Result']]
# Out:
#                                Task               Dataset      Metric  Result
# 43                    Summarization                  XSum     ROGUE-1   47.21
# 44                    Summarization                  XSum     ROGUE-2   24.56
# 45                    Summarization                  XSum     ROGUE-L   39.25
# 46                    Summarization         CNN/DailyMail     ROGUE-1   44.17
# 47                    Summarization         CNN/DailyMail     ROGUE-2   21.47
# 48                    Summarization         CNN/DailyMail     ROGUE-L   41.11
# 49                    Summarization              Newsroom     ROGUE-1   45.15
# 50                    Summarization              Newsroom     ROGUE-2   33.51
# 51                    Summarization              Newsroom     ROGUE-L   41.33
# 52                    Summarization            Multi-News     ROGUE-1   47.52
# 53                    Summarization            Multi-News     ROGUE-2   18.72
# 54                    Summarization            Multi-News     ROGUE-L   24.91
# 55                    Summarization              Gigaword     ROGUE-1   39.12
# 56                    Summarization              Gigaword     ROGUE-2   19.86
# 57                    Summarization              Gigaword     ROGUE-L   36.24
# 58                    Summarization               WikiHow     ROGUE-1   43.06
# 59                    Summarization               WikiHow     ROGUE-2   19.71
# 60                    Summarization               WikiHow     ROGUE-L   34.80
# 61                    Summarization           Reddit TIFU     ROGUE-1   26.63
# 62                    Summarization           Reddit TIFU     ROGUE-2    9.01
# 63                    Summarization           Reddit TIFU     ROGUE-L   21.64
# 64                    Summarization             BIGPATENT     ROGUE-1   53.63
# 65                    Summarization             BIGPATENT     ROGUE-2   33.16
# 66                    Summarization             BIGPATENT     ROGUE-L   42.25
# 67                    Summarization                 arXiv     ROGUE-1   44.70
# 68                    Summarization                 arXiv     ROGUE-2   17.27
# 69                    Summarization                 arXiv     ROGUE-L   25.80
# 70                    Summarization                PubMed     ROGUE-1   45.49
# 71                    Summarization                PubMed     ROGUE-2   19.90
# 72                    Summarization                PubMed     ROGUE-L   27.69
# 73                    Summarization                 AESLC     ROGUE-1   37.69
# 74                    Summarization                 AESLC     ROGUE-2   21.85
# 75                    Summarization                 AESLC     ROGUE-L   36.84
# 76                    Summarization               BillSum     ROGUE-1   57.31
# 77                    Summarization               BillSum     ROGUE-2   40.19
# 78                    Summarization               BillSum     ROGUE-L   45.82
# 181               Language Modeling   Penn Treebank (PTB)  Perplexity   56.00
# 182  Named Entity Recognition (NER)  CoNLL-2003 - English          F1   93.47
# 187  Named Entity Recognition (NER)  CoNLL-2003 - English          F1   91.64
# 188  Named Entity Recognition (NER)   CoNLL-2003 - German          F1   79.43
# 189  Named Entity Recognition (NER)  CoNLL-2002 - Spanish          F1   86.68
# 190  Named Entity Recognition (NER)     CoNLL-2002- Dutch          F1   87.81
# 191                   Text Chunking            CoNLL-2000          F1   95.29
# 192    Part-of-Speech (POS) Tagging   Penn Treebank (PTB)          F1   97.58

# %%
df[df['PaperName'].isin(common_papers)]['Dataset'].unique()
# Out:
# array(['PTB', 'CoNLL 2003', 'OntoNotes 5.0', 'WNUT-16', 'WNUT-17',
#        'OntoNotes 4.0', 'Resume', 'Weibo', 'MSRA', 'Weibo NER',
#        'Resume NER', "People's Daily", 'ATIS', 'Penn Treebank',
#        'CoNLL 2000', 'CoNLL 2002', 'SemEval 2013', 'SemEval 2010',
#        'Annotated English Gigaword', 'CNN/DailyMail', 'Gigaword', 'CoQA',
#        'DSTC7', 'SQuAD', 'CoLA', 'SST-2', 'RTE', 'QNLI', 'WNLI', 'QQP',
#        'MRPC', 'STS-B', 'WMT’14 En→Fr', 'WMT’14 En→De', "WMT'14 En→Fr",
#        "WMT'14 En→De", 'WMT14', 'WMT14 En→Fr', 'WMT14 En→De', 'IWSLT14',
#        'Billion word', 'CNN-DailyMail', 'WMT En-De', 'WMT En-Fr',
#        'WMT Zh-En', 'WMT English-German', 'Google Billion Word',
#        'WMT English-French', 'SwDA', 'MRDA', 'Switchboard Dialogue Act',
#        'CNNDM', 'XSum', 'NYT', 'CoNLL-2003', 'OntoNotes',
#        'WMT14 English-French', 'WMT14 English-German', "WMT'14 EN-FR",
#        "WMT'14 EN-DE", 'SWDA', 'Snips', 'Reddit TIFU', 'NEWSROOM',
#        'Multi-News', 'WikiHow', 'BIGPATENT', 'arXiv', 'PubMed', 'AESLC',
#        'BillSum', 'MapTask', 'IWSLT 2014', 'IWSLT 2015'], dtype=object)

# %%
tdmr_data[tdmr_data['PaperName'].isin(common_papers)]['Dataset'].unique()
# Out:
# array(['CNN/DailyMail', 'Gigaword', 'SQuAD 2.0', 'CoQA', 'SQuAD 1.1',
#        'DSTC7', 'CoLA', 'SST-2', 'MRPC', 'STS-B', 'QQP', 'MNLI-m',
#        'MNLI-mm', 'QNLI', 'RTE', 'WNLI', 'AX', 'XSum', 'Newsroom',
#        'Multi-News', 'WikiHow', 'Reddit TIFU', 'BIGPATENT', 'arXiv',
#        'PubMed', 'AESLC', 'BillSum', 'New York Times (NYT)',
#        'Ontonotes v5 - English', 'WNUT-16 - English', 'WNUT-17 - English',
#        'Ontonotes v4 - Chinese', 'Resume - Chinese', 'Weibo - Chinese',
#        'CoNLL-2003 - English', 'Penn Treebank (PTB)',
#        'CoNLL-2003 - German', 'CoNLL-2002 - Spanish', 'CoNLL-2002- Dutch',
#        'CoNLL-2000', 'WMT’14 EN-FR', 'WMT’14 EN-DE', 'IWSLT’15 EN-VI',
#        'IWSLT’14 EN-DE', 'WMT’17 EN-ZH', 'Google Billion Word',
#        'SemEval 2013 Task 13', 'SemEval 2010 Task 14', 'ATIS', 'SNIPS',
#        'Switchboard Dialog Act Corpus (SWDA)',
#        'ICSI Meeting Recorder Dialog Act Corpus (MRDA)', 'MapTask'],
#       dtype=object)

# %%
set(df[df['PaperName'].isin(common_papers)]['Dataset'].unique()).intersection(tdmr_data[tdmr_data['PaperName'].isin(common_papers)]['Dataset'].unique()
)
# Out:
# {'AESLC',
#  'ATIS',
#  'BIGPATENT',
#  'BillSum',
#  'CNN/DailyMail',
#  'CoLA',
#  'CoQA',
#  'DSTC7',
#  'Gigaword',
#  'Google Billion Word',
#  'MRPC',
#  'MapTask',
#  'Multi-News',
#  'PubMed',
#  'QNLI',
#  'QQP',
#  'RTE',
#  'Reddit TIFU',
#  'SST-2',
#  'STS-B',
#  'WNLI',
#  'WikiHow',
#  'XSum',
#  'arXiv'}

# %%
path_with_tables_captions = '/Users/Michal/Dokumenty_mac/MasterThesis/docling_tryout/results'
len(list(Path(path_with_tables_captions).iterdir()))
# Out:
# 44

# %% [markdown]
# ### Comparing results on 3 random papers

# %%
papers_to_compare = common_papers[:3]
papers_to_compare
# Out:
# ['1906.05012.pdf', '1811.09242.pdf', '1909.02188.pdf']

# %%
compare_df = df[df['PaperName'].isin(papers_to_compare)]
compare_df.shape
# Out:
# (18, 5)

# %%
compare_tdmr_data = tdmr_data[tdmr_data['PaperName'].isin(papers_to_compare)]
compare_tdmr_data.shape
# Out:
# (15, 7)

# %% [markdown]
# #### Extracted datasets comparison

# %%
compare_df['Dataset'].unique()
# Out:
# array(['ATIS', 'Annotated English Gigaword', 'SemEval 2010',
#        'SemEval 2013'], dtype=object)

# %%
compare_tdmr_data['Dataset'].unique()
# Out:
# array(['Gigaword', 'SemEval 2013 Task 13', 'SemEval 2010 Task 14', 'ATIS',
#        'SNIPS'], dtype=object)

# %% [markdown]
# ### First paper

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[0]]
# Out:
#                                   Task                     Dataset   Metric  \
# 87  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# 88  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-2
# 89  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 90  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 91  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 92  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 93  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 94  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 95  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
#
#          PaperName Result
# 87  1906.05012.pdf  40.49
# 88  1906.05012.pdf  19.01
# 89  1906.05012.pdf   2.48
# 90  1906.05012.pdf  20.94
# 91  1906.05012.pdf  28.71
# 92  1906.05012.pdf  31.42
# 93  1906.05012.pdf  34.08
# 94  1906.05012.pdf  34.94
# 95  1906.05012.pdf   36.1

# %%
compare_tdmr_data.columns
# Out:
# Index(['PaperURL', 'PaperName', 'Task', 'Dataset', 'Metric', 'Result',
#        'Comment'],
#       dtype='object')

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#              Task   Dataset   Metric       PaperName  Result
# 79  Summarization  Gigaword  ROGUE-1  1906.05012.pdf   39.11
# 80  Summarization  Gigaword  ROGUE-2  1906.05012.pdf   19.78
# 81  Summarization  Gigaword  ROGUE-L  1906.05012.pdf   36.87

# %% [markdown]
# ### Second paper

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[1]]
# Out:
#                      Task       Dataset  \
# 228  Word Sense Induction  SemEval 2010
# 229  Word Sense Induction  SemEval 2013
# 230  Word sense induction  SemEval 2010
# 231  Word sense induction  SemEval 2010
# 232  Word sense induction  SemEval 2013
# 233  Word sense induction  SemEval 2013
#
#                                           Metric       PaperName Result
# 228                                     F1-score  1811.09242.pdf   62.9
# 229                                     F1-score  1811.09242.pdf  24.37
# 230                              V-measure (V-M)  1811.09242.pdf    4.4
# 231                                F-score (F-S)  1811.09242.pdf   62.9
# 232                         Fuzzy B-cubed (F-BC)  1811.09242.pdf  24.37
# 233  Fuzzy normalized mutual information (F-NMI)  1811.09242.pdf  24.37

# %%
papers_to_compare
# Out:
# ['1906.05012.pdf', '1811.09242.pdf', '1909.02188.pdf']

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[1]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                      Task               Dataset  \
# 246  Word Sense Induction  SemEval 2013 Task 13
# 247  Word Sense Induction  SemEval 2013 Task 13
# 248  Word Sense Induction  SemEval 2013 Task 13
# 249  Word Sense Induction  SemEval 2010 Task 14
# 250  Word Sense Induction  SemEval 2010 Task 14
# 251  Word Sense Induction  SemEval 2010 Task 14
#
#                                          Metric       PaperName  Result
# 246  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    9.55
# 247                         Fuzzy B-Cubed (FBC)  1811.09242.pdf   62.20
# 248                                         AVG  1811.09242.pdf   24.37
# 249                               F-Score (F-S)  1811.09242.pdf   62.90
# 250                             V-Measure (V-M)  1811.09242.pdf   10.10
# 251                                         AVG  1811.09242.pdf   25.20

# %% [markdown]
# ### Third paper

# %%
papers_to_compare[2]
# Out:
# '1909.02188.pdf'

# %%
compare_df[compare_df['PaperName'] == papers_to_compare[2]]
# Out:
#                                      Task Dataset            Metric  \
# 78                      Intent Prediction    ATIS          Accuracy
# 79  Sentence-level Semantic Frame Parsing    ATIS  Overall Accuracy
# 80                       Intent Detection    ATIS          Accuracy
#
#          PaperName Result
# 78  1909.02188.pdf   86.5
# 79  1909.02188.pdf   86.5
# 80  1909.02188.pdf   86.5

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[2]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset            Metric  \
# 266  Intent Detection and Slot Filling    ATIS                F1
# 267  Intent Detection and Slot Filling    ATIS          Accuracy
# 268  Intent Detection and Slot Filling    ATIS  Overall-Accuracy
# 269  Intent Detection and Slot Filling   SNIPS                F1
# 270  Intent Detection and Slot Filling   SNIPS          Accuracy
# 271  Intent Detection and Slot Filling   SNIPS  Overall-Accuracy
#
#           PaperName  Result
# 266  1909.02188.pdf    95.9
# 267  1909.02188.pdf    96.9
# 268  1909.02188.pdf    86.5
# 269  1909.02188.pdf    94.2
# 270  1909.02188.pdf    98.0
# 271  1909.02188.pdf    86.9

# %% [markdown]
# ## Updated approach on 07.02

# %%
# result_json_file = 
read_json_new = read_json('/Users/Michal/Dokumenty_mac/MasterThesis/master_thesis/tdmr_extraction/gpt-4o/with_captions_updated_tables_07_02/processed_tdmr_extraction.json')
updated_df = pd.DataFrame.from_dict(read_json_new)
updated_df['PaperName'] = updated_df['PaperName'] + ".pdf"

# %%
updated_df
# Out:
#                                      Task                     Dataset  \
# 0                       Intent Prediction                        ATIS
# 1                       Intent Prediction                        ATIS
# 2                       Intent Prediction                        ATIS
# 3   Sentence-level Semantic Frame Parsing                        ATIS
# 4   Sentence-level Semantic Frame Parsing                        ATIS
# 5   Sentence-level Semantic Frame Parsing                        ATIS
# 6                            Slot Filling                        ATIS
# 7                        Intent Detection                        ATIS
# 8                        Intent Detection                        ATIS
# 9                        Intent Detection                        ATIS
# 10     Abstractive Sentence Summarization  Annotated English Gigaword
# 11     Abstractive Sentence Summarization  Annotated English Gigaword
# 12     Abstractive Sentence Summarization  Annotated English Gigaword
# 13     Abstractive Sentence Summarization  Annotated English Gigaword
# 14     Abstractive Sentence Summarization  Annotated English Gigaword
# 15     Abstractive Sentence Summarization  Annotated English Gigaword
# 16     Abstractive Sentence Summarization  Annotated English Gigaword
# 17     Abstractive Sentence Summarization  Annotated English Gigaword
# 18     Abstractive Sentence Summarization  Annotated English Gigaword
# 19     Abstractive Sentence Summarization  Annotated English Gigaword
# 20     Abstractive Sentence Summarization  Annotated English Gigaword
# 21     Abstractive Sentence Summarization  Annotated English Gigaword
# 22     Abstractive Sentence Summarization  Annotated English Gigaword
# 23     Abstractive Sentence Summarization  Annotated English Gigaword
# 24     Abstractive Sentence Summarization  Annotated English Gigaword
# 25                   Word Sense Induction                SemEval 2010
# 26                   Word Sense Induction                SemEval 2010
# 27                   Word Sense Induction                SemEval 2013
# 28                   Word Sense Induction                SemEval 2013
# 29                   Word sense induction                SemEval 2010
# 30                   Word sense induction                SemEval 2010
# 31                   Word sense induction                SemEval 2010
# 32                   Word sense induction                SemEval 2010
# 33                   Word sense induction                SemEval 2013
# 34                   Word sense induction                SemEval 2013
# 35                   Word sense induction                SemEval 2013
# 36                   Word sense induction                SemEval 2013
#
#                                          Metric  \
# 0                                      Accuracy
# 1                                      Accuracy
# 2                                      Accuracy
# 3                              Overall Accuracy
# 4                              Overall Accuracy
# 5                              Overall Accuracy
# 6                                            F1
# 7                                      Accuracy
# 8                                      Accuracy
# 9                                      Accuracy
# 10                                      ROUGE-1
# 11                                      ROUGE-1
# 12                                      ROUGE-1
# 13                                      ROUGE-1
# 14                                      ROUGE-1
# 15                                      ROUGE-2
# 16                                      ROUGE-2
# 17                                      ROUGE-2
# 18                                      ROUGE-2
# 19                                      ROUGE-2
# 20                                      ROUGE-L
# 21                                      ROUGE-L
# 22                                      ROUGE-L
# 23                                      ROUGE-L
# 24                                      ROUGE-L
# 25                                     F1-score
# 26                                     F1-score
# 27                                     F1-score
# 28                                     F1-score
# 29                              V-measure (V-M)
# 30                              V-measure (V-M)
# 31                                F-score (F-S)
# 32                                F-score (F-S)
# 33                         Fuzzy B-cubed (F-BC)
# 34                         Fuzzy B-cubed (F-BC)
# 35  Fuzzy normalized mutual information (F-NMI)
# 36  Fuzzy normalized mutual information (F-NMI)
#
#                                                Result       PaperName
# 0   [80.7, 78.9, 82.2, 82.6, 82.2, 85.7, 83.4, 86....  1909.02188.pdf
# 1                      [83.4, 82.3, 85.8, 86.2, 86.5]  1909.02188.pdf
# 2                                  [86.5, 88.2, 88.6]  1909.02188.pdf
# 3   [80.7, 78.9, 82.2, 82.6, 82.2, 85.7, 83.4, 86....  1909.02188.pdf
# 4                      [83.4, 82.3, 85.8, 86.2, 86.5]  1909.02188.pdf
# 5                                  [86.5, 88.2, 88.6]  1909.02188.pdf
# 6                                                  []  1909.02188.pdf
# 7   [80.7, 78.9, 82.2, 82.6, 82.2, 85.7, 83.4, 86....  1909.02188.pdf
# 8                      [83.4, 82.3, 85.8, 86.2, 86.5]  1909.02188.pdf
# 9                                  [86.5, 88.2, 88.6]  1909.02188.pdf
# 10    [2.58, 23.46, 32.69, 35.9, 37.82, 38.92, 40.49]  1906.05012.pdf
# 11                       [32.26, 33.15, 31.53, 39.11]  1906.05012.pdf
# 12  [29.55, 29.78, 33.78, 32.67, 34.07, 36.15, 36....  1906.05012.pdf
# 13                [33.85, 37.69, 38.34, 38.89, 39.11]  1906.05012.pdf
# 14                       [32.26, 34.51, 39.02, 39.11]  1906.05012.pdf
# 15     [0.0, 7.67, 11.74, 13.32, 16.79, 17.72, 19.01]  1906.05012.pdf
# 16                        [15.3, 15.93, 13.77, 19.78]  1906.05012.pdf
# 17  [11.32, 11.89, 15.97, 15.59, 16.35, 17.54, 18....  1906.05012.pdf
# 18                [15.83, 18.62, 19.35, 19.64, 19.78]  1906.05012.pdf
# 19                        [15.3, 16.55, 19.21, 19.78]  1906.05012.pdf
# 20    [2.48, 20.94, 28.71, 31.42, 34.08, 34.94, 36.1]  1906.05012.pdf
# 21                       [30.19, 31.21, 27.96, 36.87]  1906.05012.pdf
# 22  [26.42, 26.97, 31.15, 30.64, 31.78, 33.63, 33....  1906.05012.pdf
# 23                [31.14, 34.38, 34.97, 36.67, 36.87]  1906.05012.pdf
# 24                       [30.19, 31.17, 36.02, 36.87]  1906.05012.pdf
# 25  [60.7, 61.5, 44.4, 35.1, 23.1, 57.7, 55.1, 59....  1811.09242.pdf
# 26  [{'Model': 'LDA', 'Scores': [41.4, 13.3, 8.9, ...  1811.09242.pdf
# 27  [15.92, 17.02, 19.3, 9.64, 13.22, 19.89, 20.58...  1811.09242.pdf
# 28  [41.4, 13.3, 8.9, 9.0, 42.5, 44.1, 41.6, 41.3,...  1811.09242.pdf
# 29  [4.4, 4.5, 11.5, 15.2, 21.4, 2.9, 9.8, 9.2, 8....  1811.09242.pdf
# 30  [41.4, 13.3, 8.9, 9.0, 42.5, 44.1, 41.6, 41.3,...  1811.09242.pdf
# 31  [60.7, 61.5, 44.4, 35.1, 23.1, 57.7, 55.1, 59....  1811.09242.pdf
# 32  [{'Model': 'LDA', 'Scores': [41.4, 13.3, 8.9, ...  1811.09242.pdf
# 33                                     [22.16, 24.37]  1811.09242.pdf
# 34  [41.4, 13.3, 8.9, 9.0, 42.5, 44.1, 41.6, 41.3,...  1811.09242.pdf
# 35                                     [22.16, 24.37]  1811.09242.pdf
# 36  [41.4, 13.3, 8.9, 9.0, 42.5, 44.1, 41.6, 41.3,...  1811.09242.pdf

# %%
updated_df_exploded = updated_df.explode('Result', ignore_index=True)

# %% [markdown]
# ### First paper

# %%
updated_df_exploded[updated_df_exploded['PaperName'] == papers_to_compare[0]]
# Out:
#                                    Task                     Dataset   Metric  \
# 52   Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# 53   Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# 54   Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# 55   Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# 56   Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-1
# ..                                  ...                         ...      ...
# 137  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 138  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 139  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 140  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
# 141  Abstractive Sentence Summarization  Annotated English Gigaword  ROUGE-L
#
#     Result       PaperName
# 52    2.58  1906.05012.pdf
# 53   23.46  1906.05012.pdf
# 54   32.69  1906.05012.pdf
# 55    35.9  1906.05012.pdf
# 56   37.82  1906.05012.pdf
# ..     ...             ...
# 137  36.87  1906.05012.pdf
# 138  30.19  1906.05012.pdf
# 139  31.17  1906.05012.pdf
# 140  36.02  1906.05012.pdf
# 141  36.87  1906.05012.pdf
#
# [90 rows x 5 columns]

# %%
updated_df_exploded[updated_df_exploded['PaperName'] == papers_to_compare[0]].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                                       Result  \
# Task                               Dataset                    Metric
# Abstractive Sentence Summarization Annotated English Gigaword ROUGE-1  40.49
#                                                               ROUGE-2  19.78
#                                                               ROUGE-L  36.87
#
#                                                                             PaperName
# Task                               Dataset                    Metric
# Abstractive Sentence Summarization Annotated English Gigaword ROUGE-1  1906.05012.pdf
#                                                               ROUGE-2  1906.05012.pdf
#                                                               ROUGE-L  1906.05012.pdf

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[0]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#              Task   Dataset   Metric       PaperName  Result
# 79  Summarization  Gigaword  ROGUE-1  1906.05012.pdf   39.11
# 80  Summarization  Gigaword  ROGUE-2  1906.05012.pdf   19.78
# 81  Summarization  Gigaword  ROGUE-L  1906.05012.pdf   36.87

# %% [markdown]
# ### Difference caused:
#
# In the other table within this paper there's a higher value extracted than the one reported by authors

# %% [markdown]
# ### Second paper

# %%
papers_to_compare[1]
# Out:
# '1811.09242.pdf'

# %%
updated_df_exploded['float'] = updated_df_exploded['Result'].apply(lambda x: True if type(x) == float else False)

# %%
updated_df_exploded[(updated_df_exploded['PaperName'] == papers_to_compare[1])].groupby(['Task', 'Dataset', 'Metric'])['Result'].tail()# .groupby(['Task', 'Dataset', 'Metric'])
# Out:
# 153                                                 61.2
# 154    {'Model': 'LDA', 'Scores': [41.4, 13.3, 8.9, 9...
# 155    {'Model': 'HC', 'Scores': [42.5, 44.1, 41.6, 4...
# 156    {'Model': 'STM', 'Scores': [44.9, 44.4, 44.9, ...
# 157    {'Model': 'AutoSense', 'Scores': [44.4, 45.5, ...
# 184                                                 41.9
# 185                                                 44.4
# 186                                                 45.5
# 187                                                 46.6
# 188                                                 46.5
# 212                                                 41.9
# 213                                                 44.4
# 214                                                 45.5
# 215                                                 46.6
# 216                                                 46.5
# 228                                                 61.2
# 229    {'Model': 'LDA', 'Scores': [41.4, 13.3, 8.9, 9...
# 230    {'Model': 'HC', 'Scores': [42.5, 44.1, 41.6, 4...
# 231    {'Model': 'STM', 'Scores': [44.9, 44.4, 44.9, ...
# 232    {'Model': 'AutoSense', 'Scores': [44.4, 45.5, ...
# 246                                                 41.9
# 247                                                 44.4
# 248                                                 45.5
# 249                                                 46.6
# 250                                                 46.5
# 264                                                 41.9
# 265                                                 44.4
# 266                                                 45.5
# 267                                                 46.6
# 268                                                 46.5
# Name: Result, dtype: object

# %%
compare_tdmr_data[(compare_tdmr_data['PaperName'] == papers_to_compare[1]) & (updated_df_exploded['float'] == True)].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
# /var/folders/jm/q7s8glj14mj8tqv8r15tr1wc0000gp/T/ipykernel_11157/2301952649.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   compare_tdmr_data[(compare_tdmr_data['PaperName'] == papers_to_compare[1]) & (updated_df_exploded['float'] == True)].groupby(['Task', 'Dataset', 'Metric']).max()
#                                                                                                                   PaperURL  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                         https://arxiv.org/pdf/1811.09242.pdf
#                                           F-Score (F-S)                               https://arxiv.org/pdf/1811.09242.pdf
#                                           V-Measure (V-M)                             https://arxiv.org/pdf/1811.09242.pdf
#                      SemEval 2013 Task 13 AVG                                         https://arxiv.org/pdf/1811.09242.pdf
#                                           Fuzzy B-Cubed (FBC)                         https://arxiv.org/pdf/1811.09242.pdf
#                                           Fuzzy normalized mutual information (FNMI)  https://arxiv.org/pdf/1811.09242.pdf
#
#                                                                                            PaperName  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                         1811.09242.pdf
#                                           F-Score (F-S)                               1811.09242.pdf
#                                           V-Measure (V-M)                             1811.09242.pdf
#                      SemEval 2013 Task 13 AVG                                         1811.09242.pdf
#                                           Fuzzy B-Cubed (FBC)                         1811.09242.pdf
#                                           Fuzzy normalized mutual information (FNMI)  1811.09242.pdf
#
#                                                                                       Result  \
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                          25.20
#                                           F-Score (F-S)                                62.90
#                                           V-Measure (V-M)                              10.10
#                      SemEval 2013 Task 13 AVG                                          24.37
#                                           Fuzzy B-Cubed (FBC)                          62.20
#                                           Fuzzy normalized mutual information (FNMI)    9.55
#
#                                                                                      Comment
# Task                 Dataset              Metric
# Word Sense Induction SemEval 2010 Task 14 AVG                                            NaN
#                                           F-Score (F-S)                                  NaN
#                                           V-Measure (V-M)                                NaN
#                      SemEval 2013 Task 13 AVG                                            NaN
#                                           Fuzzy B-Cubed (FBC)                            NaN
#                                           Fuzzy normalized mutual information (FNMI)     NaN

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[1]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                      Task               Dataset  \
# 246  Word Sense Induction  SemEval 2013 Task 13
# 247  Word Sense Induction  SemEval 2013 Task 13
# 248  Word Sense Induction  SemEval 2013 Task 13
# 249  Word Sense Induction  SemEval 2010 Task 14
# 250  Word Sense Induction  SemEval 2010 Task 14
# 251  Word Sense Induction  SemEval 2010 Task 14
#
#                                          Metric       PaperName  Result
# 246  Fuzzy normalized mutual information (FNMI)  1811.09242.pdf    9.55
# 247                         Fuzzy B-Cubed (FBC)  1811.09242.pdf   62.20
# 248                                         AVG  1811.09242.pdf   24.37
# 249                               F-Score (F-S)  1811.09242.pdf   62.90
# 250                             V-Measure (V-M)  1811.09242.pdf   10.10
# 251                                         AVG  1811.09242.pdf   25.20

# %% [markdown]
# ### Third paper

# %%
third_paper_json_file_path = '/Users/Michal/Dokumenty_mac/MasterThesis/master_thesis/tdmr_extraction/gpt-4o/with_captions_updated_tables_07_02_new_table_representation/1909.02188/1909.02188_tdmr_extraction.json'
third_paper_json_file = read_json(Path(third_paper_json_file_path))
thrid_papeR_df = pd.DataFrame.from_dict(third_paper_json_file)

# %%
thrid_paper_df = thrid_papeR_df.explode('Result', ignore_index=True)

# %%
updated_df_exploded[updated_df_exploded['PaperName'] == papers_to_compare[2]].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                                Result  \
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           88.6
# Intent Prediction                     ATIS    Accuracy           88.6
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   88.6
# Slot Filling                          ATIS    F1                  NaN
#
#                                                                      PaperName  \
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy          1909.02188.pdf
# Intent Prediction                     ATIS    Accuracy          1909.02188.pdf
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy  1909.02188.pdf
# Slot Filling                          ATIS    F1                1909.02188.pdf
#
#                                                                 float
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           True
# Intent Prediction                     ATIS    Accuracy           True
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   True
# Slot Filling                          ATIS    F1                 True

# %%
thrid_paper_df['float'] = thrid_paper_df['Result'].apply(lambda x: True if type(x) == float else False)
thrid_paper_df[thrid_paper_df['float'] == True].groupby(['Task', 'Dataset', 'Metric']).max()
# Out:
#                                                                Result  float
# Task                                  Dataset Metric
# Intent Detection                      ATIS    Accuracy           97.5   True
#                                       SNIPS   Accuracy           99.0   True
# Intent Prediction                     ATIS    Accuracy           97.5   True
#                                       SNIPS   Accuracy           99.0   True
# Sentence-level Semantic Frame Parsing ATIS    Overall Accuracy   88.6   True
#                                       SNIPS   Overall Accuracy   92.9   True
# Slot Filling                          ATIS    F1                 96.1   True
#                                               F1 Score           96.1   True
#                                       SNIPS   F1                 97.0   True
#                                               F1 Score           97.0   True

# %%
compare_tdmr_data[compare_tdmr_data['PaperName'] == papers_to_compare[2]][['Task', 'Dataset', 'Metric','PaperName', 'Result']]
# Out:
#                                   Task Dataset            Metric  \
# 266  Intent Detection and Slot Filling    ATIS                F1
# 267  Intent Detection and Slot Filling    ATIS          Accuracy
# 268  Intent Detection and Slot Filling    ATIS  Overall-Accuracy
# 269  Intent Detection and Slot Filling   SNIPS                F1
# 270  Intent Detection and Slot Filling   SNIPS          Accuracy
# 271  Intent Detection and Slot Filling   SNIPS  Overall-Accuracy
#
#           PaperName  Result
# 266  1909.02188.pdf    95.9
# 267  1909.02188.pdf    96.9
# 268  1909.02188.pdf    86.5
# 269  1909.02188.pdf    94.2
# 270  1909.02188.pdf    98.0
# 271  1909.02188.pdf    86.9

# %%
compare_tdmr_data
# Out:
#                                  PaperURL       PaperName  \
# 79   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 80   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 81   https://arxiv.org/pdf/1906.05012.pdf  1906.05012.pdf
# 246  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 247  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 248  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 249  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 250  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 251  https://arxiv.org/pdf/1811.09242.pdf  1811.09242.pdf
# 266  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 267  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 268  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 269  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 270  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
# 271  https://arxiv.org/pdf/1909.02188.pdf  1909.02188.pdf
#
#                                   Task               Dataset  \
# 79                       Summarization              Gigaword
# 80                       Summarization              Gigaword
# 81                       Summarization              Gigaword
# 246               Word Sense Induction  SemEval 2013 Task 13
# 247               Word Sense Induction  SemEval 2013 Task 13
# 248               Word Sense Induction  SemEval 2013 Task 13
# 249               Word Sense Induction  SemEval 2010 Task 14
# 250               Word Sense Induction  SemEval 2010 Task 14
# 251               Word Sense Induction  SemEval 2010 Task 14
# 266  Intent Detection and Slot Filling                  ATIS
# 267  Intent Detection and Slot Filling                  ATIS
# 268  Intent Detection and Slot Filling                  ATIS
# 269  Intent Detection and Slot Filling                 SNIPS
# 270  Intent Detection and Slot Filling                 SNIPS
# 271  Intent Detection and Slot Filling                 SNIPS
#
#                                          Metric  Result Comment
# 79                                      ROGUE-1   39.11     NaN
# 80                                      ROGUE-2   19.78     NaN
# 81                                      ROGUE-L   36.87     NaN
# 246  Fuzzy normalized mutual information (FNMI)    9.55     NaN
# 247                         Fuzzy B-Cubed (FBC)   62.20     NaN
# 248                                         AVG   24.37     NaN
# 249                               F-Score (F-S)   62.90     NaN
# 250                             V-Measure (V-M)   10.10     NaN
# 251                                         AVG   25.20     NaN
# 266                                          F1   95.90     NaN
# 267                                    Accuracy   96.90     NaN
# 268                            Overall-Accuracy   86.50     NaN
# 269                                          F1   94.20     NaN
# 270                                    Accuracy   98.00     NaN
# 271                            Overall-Accuracy   86.90     NaN
